# %%
import json
import requests

# %%
# API - To fetch temperature of a city
city_name = input("Enter city name: ")
api_key = ""  # Enter your API key here remove it after use for security reasons
api_url = f"https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}"
get_server_information = requests.get(api_url)
Data = get_server_information.json()
print(Data)
temperature_kelvin = Data['main']['temp']
temperature_celsius = temperature_kelvin - 273.15
print(f"The temperature in {city_name} is {temperature_celsius:.2f}°C")
D = Data['weather'][0]['description']
print(f"The weather description in {city_name} is: {D}")
T = Data['main']
print(f"The temperature details are: {T}")
# Out:
# {'coord': {'lon': 74.0833, 'lat': 15.3333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 301.36, 'feels_like': 303.04, 'temp_min': 301.36, 'temp_max': 301.36, 'pressure': 1009, 'humidity': 61, 'sea_level': 1009, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 3.46, 'deg': 86, 'gust': 7.04}, 'clouds': {'all': 63}, 'dt': 1761020922, 'sys': {'type': 1, 'id': 9233, 'country': 'IN', 'sunrise': 1761008190, 'sunset': 1761050388}, 'timezone': 19800, 'id': 1271157, 'name': 'Goa', 'cod': 200}
# The temperature in Goa is 28.21°C
# The weather description in Goa is: broken clouds
# The temperature details are: {'temp': 301.36, 'feels_like': 303.04, 'temp_min': 301.36, 'temp_max': 301.36, 'pressure': 1009, 'humidity': 61, 'sea_level': 1009, 'grnd_level': 996}

# %%
Pretty_data = json.dumps(Data, indent=4)
print(Pretty_data)
# Out:
# {
#     "coord": {
#         "lon": 77.2167,
#         "lat": 28.6667
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 300.54,
#         "feels_like": 300.1,
#         "temp_min": 300.54,
#         "temp_max": 300.54,
#         "pressure": 1012,
#         "humidity": 36,
#         "sea_level": 1012,
#         "grnd_level": 986
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.4,
#         "deg": 356,
#         "gust": 4.15
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1760289929,
#     "sys": {
#         "country": "IN",
#         "sunrise": 1760230195,
#         "sunset": 1760271904
#     },
#     "timezone": 19800,
#     "id": 1273294,
#     "name": "Delhi",
#     "cod": 200
# }
